# %% [markdown]
# - Membuat ETL Pipeline menggunakan Luigi
# - Proposed ETL Pipeline design adalah sebagai berikut
#
# <center>
# <img src="https://sekolahdata-assets.s3.ap-southeast-1.amazonaws.com/notebook-images/mde-intro-to-data-eng/15-01.png" width=70%>
# </center>
#
# - Task yang harus dilakukan adalah:
#     1. Membuat Pipeline Extract dari source:
#         - [API Payment Data](https://shandytepe.github.io/payment.json)
#         - Database Hotel
#
#        Setelah berhasil melakukan Extract, simpan output `.csv` ke dalam folder `live_class_w8/data/raw`
#
#     2. Membuat Pipeline Validation dari Pipeline Extract data. Proses validasi yang dilakukan adalah:
#         - Check Data Shape
#         - Check Data Types
#         - Check Missing Values
#
#     3. Membuat Pipeline Transform dari Pipeline Extract Data. Proses yang dilakukan adalah:
#         - Join Data dari beberapa source, menjadi satu table data yang baru
#             - Source yang digunakan untuk membuat table baru adalah:
#                 - `payment` (API Payment Data)
#                 - `reservation` (DB Hotel)
#                 - `customer` (DB Hotel)
#
#
# <center>
# <img src="https://sekolahdata-assets.s3.ap-southeast-1.amazonaws.com/notebook-images/mde-intro-to-data-eng/15-02.png" width=80%>
# </center>
#
#
# - Cleaning data
#
#     Setelah berhasil melakukan proses Transform, simpan output `.csv` ke dalam folder `live_class_w8/data/transform`
#
#     4. Membuat Pipeline Load dari Pipeline Transform. Memasukkan table yang baru ke dalam Data Warehouse yang sudah dibuat. Untuk membuat Data Warehouse, bisa melihat dokumentasi di https://github.com/shandytepe/live-class-w8-intro-to-data-eng/tree/main/docker-db
#
#     5. Menggabungkan semua Pipeline menjadi satu dengan menggunakan Luigi
#
#     6. Set schedule pada Pipelien yang sudah dibuat dengan menggunakan `cron`. Set schedule pipeline untuk dijalankan tiap 2 menit sekali. Sehingga, syntax `cron` nya adalah sebagai berikut
#
#         ```bash
#         */2 * * * * /path/to/pipeline.sh
#         ```
#
#     7. Melakukan proses `UPSERT` untuk mengecek robustness dari pipeline yang dibuat

# %% [markdown]
# # Extract

# %% [markdown]
# ## Data Hotel

# %%
import requests
import json
import pandas as pd

# URL of the JSON file
url = "https://shandytepe.github.io/payment.json"

# Fetch the JSON file from the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the JSON content
    data = response.json()  # Automatically parses JSON into a Python dictionary
    print(data)  # Print the JSON content
else:
    print(f"Failed to fetch JSON. HTTP Status Code: {response.status_code}")
# Out:
# {'payment_data': [{'payment_id': 1, 'reservation_id': 1, 'provider': 'Ovo', 'account_number': 38137149, 'payment_status': 'Success', 'payment_date': '2020-10-20 17:07:04.406780', 'expire_date': '2020-10-28 18:10:37.175108'}, {'payment_id': 2, 'reservation_id': 2, 'provider': 'BCA', 'account_number': 42103729, 'payment_status': 'Success', 'payment_date': '2015-02-28 16:44:56.703511', 'expire_date': '2015-03-08 05:27:33.443131'}, {'payment_id': 3, 'reservation_id': 3, 'provider': 'Permata', 'account_number': 58689635, 'payment_status': 'Success', 'payment_date': '2022-04-03 13:27:30.811447', 'expire_date': '2022-04-06 14:20:57.846492'}, {'payment_id': 4, 'reservation_id': 4, 'provider': 'BNI', 'account_number': 107161965, 'payment_status': 'Success', 'payment_date': '2019-10-04 08:39:56.034805', 'expire_date': '2019-10-08 02:01:21.209415'}, {'payment_id': 5, 'reservation_id': 5, 'provider': 'BSI', 'account_number': 14334131, 'payment_status': 'Failed', 'payment_date': None, 'expire_date': '2020-06-14 12:02:55.669148'}, {'payment_id': 6, 'reservation_id': 6, 'provider': 'Ovo', 'account_number': 43583173, 'payment_status': 'Waiting', 'payment_date': None, 'expire_date': '2020-03-25 03:35:27.294069'}, {'payment_id': 7, 'reservation_id': 7, 'provider': 'BSI', 'account_number': 21381685, 'payment_status': 'Waiting', 'payment_date': None, 'expire_date': '2017-10-12 03:15:31.976142'}, {'payment_id': 8, 'reservation_id': 8, 'provider': 'Permata', 'account_number': 119636925, 'payment_status': 'Success', 'payment_date': '2019-07-06 00:27:04.653808', 'expire_date': '2019-07-16 05:38:12.603096'}, {'payment_id': 9, 'reservation_id': 9, 'provider': 'Mandiri', 'account_number': 128447299, 'payment_status': 'Success', 'payment_date': '2020-10-22 21:58:00.410610', 'expire_date': '2020-11-07 21:05:56.055206'}, {'payment_id': 10, 'reservation_id': 10, 'provider': 'BCA', 'account_number': 21032743, 'payment_status': 'Failed', 'payment_date': None, 'expire_date': '2021-03-23 15:28:53.857496'}, {'payment_id': 11, 'reservation_id': 11, 'provider': 'BCA', 'account_number': 16173439, 'payment_status': 'Success', 'payment_date': '2015-12-30 19:38:38.538543', 'expire_date': '2016-01-04 23:05:09.802748'}, {'payment_id': 12, 'reservation_id': 12, 'provider': 'Mandiri', 'account_number': 104632264, 'payment_status': 'Success', 'payment_date': '2016-04-20 11:00:30.806322', 'expire_date': '2016-04-29 02:21:20.891066'}, {'payment_id': 13, 'reservation_id': 13, 'provider': 'BSI', 'account_number': 43534397, 'payment_status': 'Failed', 'payment_date': None, 'expire_date': '2021-03-09 03:35:10.487369'}, {'payment_id': 14, 'reservation_id': 14, 'provider': 'BNI', 'account_number': 49889648, 'payment_status': 'Success', 'payment_date': '2015-08-30 02:50:08.222347', 'expire_date': '2015-09-06 15:20:00.703303'}, {'payment_id': 15, 'reservation_id': 15, 'provider': 'Ovo', 'account_number': 18430413, 'payment_status': 'Success', 'payment_date': '2015-08-25 14:16:14.426967', 'expire_date': '2015-09-11 10:50:49.605705'}, {'payment_id': 16, 'reservation_id': 16, 'provider': 'BSI', 'account_number': 50658732, 'payment_status': 'Success', 'payment_date': '2015-06-20 02:46:39.973862', 'expire_date': '2015-07-14 03:01:07.619775'}, {'payment_id': 17, 'reservation_id': 17, 'provider': 'Permata', 'account_number': 127295361, 'payment_status': 'Waiting', 'payment_date': None, 'expire_date': '2017-07-04 16:06:26.397032'}, {'payment_id': 18, 'reservation_id': 18, 'provider': 'Ovo', 'account_number': 17623865, 'payment_status': 'Failed', 'payment_date': None, 'expire_date': '2022-02-07 12:28:06.762768'}, {'payment_id': 19, 'reservation_id': 19, 'provider': 'Permata', 'account_number': 45720659, 'payment_status': 'Success', 'payment_date': '2020-08-13 21:31:51.720690', 'expire_date': '2020-08-18 00:19:21.200788'}, {'payment_id': 20, 'reservation_id': 20, 'provider': 'BRI', 'account_number': 24522616, 'payment_status': 'Success', 'payment_date': '2019-04-29 02:30:35.993787', 'expire_d ...

# %%
raw_data = data['payment_data']

# %%
df = pd.DataFrame(raw_data)
df
# Out:
#      payment_id  reservation_id provider  account_number payment_status  \
# 0             1               1      Ovo        38137149        Success
# 1             2               2      BCA        42103729        Success
# 2             3               3  Permata        58689635        Success
# 3             4               4      BNI       107161965        Success
# 4             5               5      BSI        14334131         Failed
# ..          ...             ...      ...             ...            ...
# 396         397             397  Permata        87836019        Success
# 397         398             398  Mandiri        50997930         Failed
# 398         399             399      Ovo        44305033        Success
# 399         400             400      BNI        84875963        Success
# 400         401             401      BCA        11111111        Success
#
#                    payment_date                 expire_date
# 0    2020-10-20 17:07:04.406780  2020-10-28 18:10:37.175108
# 1    2015-02-28 16:44:56.703511  2015-03-08 05:27:33.443131
# 2    2022-04-03 13:27:30.811447  2022-04-06 14:20:57.846492
# 3    2019-10-04 08:39:56.034805  2019-10-08 02:01:21.209415
# 4                          None  2020-06-14 12:02:55.669148
# ..                          ...                         ...
# 396  2018-08-05 09:22:05.983116  2018-08-27 12:44:56.532991
# 397                        None  2022-04-19 12:35:51.127022
# 398  2015-12-12 22:35:15.569310  2015-12-19 19:28:08.809478
# 399  2021-07-29 16:38:06.052542  2021-08-02 22:27:28.713637
# 400  2024-02-14 00:30:15.052542  2024-02-15 00:30:15.052542
#
# [401 rows x 7 columns]

# %% [markdown]
# ## Make Connection Database

# %%
import os
from dotenv import load_dotenv
from sqlalchemy import create_engine
from typing import Optional

def postgres_engine() -> Optional[create_engine]:
    """
    Create and return a SQLAlchemy engine for a PostgreSQL database.

    Returns:
        Optional[create_engine]: A SQLAlchemy engine object, or None if an error occurs.
    """
    # Load environment variables from .env file
    load_dotenv("Week 8/.env")

    # Fetch environment variables
    db_user = os.getenv('DB_USER')
    db_password = os.getenv('DB_PASSWORD')
    db_host = os.getenv('DB_HOST')
    db_port = os.getenv('DB_PORT')
    db_name = os.getenv('DB_NAME')

    # Debug: Print the retrieved values
    print(f"DB_USER: {db_user}")
    print(f"DB_PASSWORD: {db_password}")
    print(f"DB_HOST: {db_host}")
    print(f"DB_PORT: {db_port}")
    print(f"DB_NAME: {db_name}")

    # Check if all required environment variables are set
    if not all([db_user, db_password, db_host, db_port, db_name]):
        raise ValueError("One or more required environment variables are not set.")

    # Create the database URL
    database_url = f'postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}'

    # Create and return the engine
    engine = create_engine(database_url)
    return engine

# %%
try:
    engine = postgres_engine()
    print("Successfully connected to the database")
    # Perform database operations
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# DB_USER: postgres
# DB_PASSWORD: cobapassword
# DB_HOST: localhost
# DB_PORT: 5434
# DB_NAME: hotel_analysis_db
# Successfully connected to the database

# %% [markdown]
# ## Retrieve Table from DB

# %%
def read_sql(table_name: str) -> pd.DataFrame:
    # Query the database
    query = f"SELECT * FROM public.{table_name};"
    df = pd.read_sql(query, engine)

    # Display the results
    return df  # Return the DataFrame

# %%
# Call the function and store the result
df_reservation = read_sql('reservation')
df_customer = read_sql('customer')

df_customer.head()
df_reservation.head()
# Out:
# 398 2016-01-19 10:19:12.907 2016-01-26 08:08:00.170 2016-02-08 21:50:36.990
# 399 2016-06-22 16:38:50.950 2016-07-01 17:54:37.944 2016-07-08 15:56:10.137
#
#      total_price                                             review  rating  \
# 0      1000000.0  probably ca n't wrong, hotel welcome respite c...       3
# 1     13000000.0  fun place went boyfriend time, separated soon ...       2
# 2      9000000.0  excellent hotel money picked hotel based revie...       5
# 3      3000000.0  hell argonaut changed planned birthday getaway...       1
# 4      1000000.0  fantastic place stay sf stayed nov 9 2008 room...       1
# ..           ...                                                ...     ...
# 395   13000000.0  great location great service stayed excellent ...       2
# 396    3000000.0  lucky discovery having spent months florence y...       2
# 397   11000000.0  great room location service price recently sta...       3
# 398    7000000.0  askanischer hof, hotel, family stayed askanisc...       1
# 399    1000000.0  bit obviously invested lot make good hotel, 1-...       4
#
#                   created_at_y
# 0   2025-01-26 06:11:04.638130
# 1   2025-01-26 06:11:04.616223
# 2   2025-01-26 06:11:04.693162
# 3   2025-01-26 06:11:04.695094
# 4   2025-01-26 06:11:04.642593
# ..                         ...
# 395 2025-01-26 06:11:04.681145
# 396 2025-01-26 06:11:04.647813
# 397 2025-01-26 06:11:04.624541
# 398 2025-01-26 06:11:04.663612
# 399 2025-01-26 06:11:04.619907
#
# [400 rows x 14 columns]

# %%
final_df = pd.merge(df_cusXres, df, how='inner', on='reservation_id')

# %%
final_df.head()
# Out:
#    customer_id first_name   last_name                        email  \
# 0            2   Estiawan     Saragih  estiawansaragih@hotmail.com
# 1            4     Drajat  Nainggolan   drajatnainggolan@yahoo.com
# 2            5      Simon      Wacana      simonwacana@hotmail.com
# 3            9      Catur     Maryadi       caturmaryadi@yahoo.com
# 4           11      Najwa    Simbolon      najwasimbolon@yahoo.com
#
#                 phone               created_at_x  reservation_id  \
# 0     +62-62-782-9299 2024-02-09 13:59:44.733151             139
# 1    +62-042-726-1498 2024-02-09 13:59:44.733151              49
# 2     (0007) 948 5515 2024-02-09 13:59:44.733151             372
# 3  +62 (618) 214 3988 2024-02-09 13:59:44.733151             384
# 4     (0276) 921-7073 2024-02-09 13:59:44.733151             164
#
#          reservation_date              start_date                end_date  \
# 0 2016-08-30 18:52:49.985 2016-09-20 18:18:02.814 2016-09-25 21:35:42.582
# 1 2021-09-11 04:17:09.909 2021-10-02 02:48:59.764 2021-10-04 09:03:50.491
# 2 2018-05-01 20:26:20.625 2018-05-28 17:52:10.698 2018-06-04 10:00:05.209
# 3 2023-07-04 00:32:43.303 2023-08-03 04:00:49.376 2023-08-15 02:53:20.540
# 4 2018-02-18 05:46:32.044 2018-03-10 12:02:59.063 2018-03-23 09:23:56.599
#
#    total_price                                             review  rating  \
# 0    1000000.0  probably ca n't wrong, hotel welcome respite c...       3
# 1   13000000.0  fun place went boyfriend time, separated soon ...       2
# 2    9000000.0  excellent hotel money picked hotel based revie...       5
# 3    3000000.0  hell argonaut changed planned birthday getaway...       1
# 4    1000000.0  fantastic place stay sf stayed nov 9 2008 room...       1
#
#                 created_at_y  payment_id provider  account_number  \
# 0 2025-01-26 06:11:04.638130         139      Ovo        16640674
# 1 2025-01-26 06:11:04.616223          49     Dana        76380741
# 2 2025-01-26 06:11:04.693162         372      Ovo        71579340
# 3 2025-01-26 06:11:04.695094         384  Permata       126704617
# 4 2025-01-26 06:11:04.642593         164      BSI       124214471
#
#   payment_status                payment_date                 expire_date
# 0        Success  2016-09-15 14:06:21.733799  2016-09-20 18:18:02.814967
# 1        Success  2021-09-30 22:51:39.392363  2021-10-02 02:48:59.764712
# 2        Waiting                        None  2018-05-28 17:52:10.698413
# 3         Failed                        None  2023-08-03 04:00:49.376104
# 4        Success  2018-03-07 00:43:44.620445  2018-03-10 12:02:59.063171

# %% [markdown]
# ### Create New Columns

# %%
"""
 column nama full customer
 column total payment dengan IDR
 column email_domain
"""
def handling_col():
    if 'full_name' not in final_df.columns:
        final_df['full_name'] = final_df['first_name'] + ' ' + final_df['last_name']
    if 'total_price' in final_df.columns:
        final_df['currency'] = 'IDR'
    if 'email_domain' not in final_df.columns:
        final_df['email_domain'] = final_df['email'].str.split('@').str[1]

# %%
handling_col()

# %%
final_df.T
# Out:
#                                                                 0    \
# customer_id                                                       2
# first_name                                                 Estiawan
# last_name                                                   Saragih
# email                                   estiawansaragih@hotmail.com
# phone                                               +62-62-782-9299
# created_at_x                             2024-02-09 13:59:44.733151
# reservation_id                                                  139
# reservation_date                         2016-08-30 18:52:49.985000
# start_date                               2016-09-20 18:18:02.814000
# end_date                                 2016-09-25 21:35:42.582000
# total_price                                               1000000.0
# review            probably ca n't wrong, hotel welcome respite c...
# rating                                                            3
# created_at_y                             2025-01-26 06:11:04.638130
# payment_id                                                      139
# provider                                                        Ovo
# account_number                                             16640674
# payment_status                                              Success
# payment_date                             2016-09-15 14:06:21.733799
# expire_date                              2016-09-20 18:18:02.814967
# full_name                                          Estiawan Saragih
# currency                                                        IDR
# email_domain                                            hotmail.com
#
#                                                                 1    \
# customer_id                                                       4
# first_name                                                   Drajat
# last_name                                                Nainggolan
# email                                    drajatnainggolan@yahoo.com
# phone                                              +62-042-726-1498
# created_at_x                             2024-02-09 13:59:44.733151
# reservation_id                                                   49
# reservation_date                         2021-09-11 04:17:09.909000
# start_date                               2021-10-02 02:48:59.764000
# end_date                                 2021-10-04 09:03:50.491000
# total_price                                              13000000.0
# review            fun place went boyfriend time, separated soon ...
# rating                                                            2
# created_at_y                             2025-01-26 06:11:04.616223
# payment_id                                                       49
# provider                                                       Dana
# account_number                                             76380741
# payment_status                                              Success
# payment_date                             2021-09-30 22:51:39.392363
# expire_date                              2021-10-02 02:48:59.764712
# full_name                                         Drajat Nainggolan
# currency                                                        IDR
# email_domain                                              yahoo.com
#
#                                                                 2    \
# customer_id                                                       5
# first_name                                                    Simon
# last_name                                                    Wacana
# email                                       simonwacana@hotmail.com
# phone                                               (0007) 948 5515
# created_at_x                             2024-02-09 13:59:44.733151
# reservation_id                                                  372
# reservation_date                         2018-05-01 20:26:20.625000
# start_date                               2018-05-28 17:52:10.698000
# end_date                                 2018-06-04 10:00:05.209000
# total_price                                               9000000.0
# review            excellent hotel money picked hotel based revie...
# rating                                                            5
# created_at_y                             2025-01-26 06:11:04.693162
# payment_id                                                      372
# provider                                                        Ovo
# account_number                                             71579340
# payment_status                                              Waiting
# payment_date                                                   None
# expire_date                              2018-05-28 17:52:10.698413
# full_name                                              Simon Wacana
# currency                                                        IDR
# email_domain                                            hotmail.com
#
#                                                                 3    \
# customer_id                                                       9
# first_name                                                    Catur
# last_name                                                   Maryadi
# email                                        caturmaryadi@yahoo.com
# phone                                            +62 (618) 214 3988
# created_at_x                             2024-02-09 13:59:44.733151
# reservation_id                                                  384
# reservation_date                         2023-07-04 00:32:43.303000
# start_date                               2023-08-03 04:00:49.376000
# end_date                                 2023-08-15 02:53:20.540000
# total_price                                               3000000.0
# review            hell argonaut changed planned birthday getaway...
# rating                                                            1
# created_at_y                             2025-01-26 06:11:04.695094
# payment_id                                                      384
# provider                                                    Permata
# account_number                                            126704617
# payment_status                                               Failed
# payment_date                                                   None
# expire_date                              2023-08-03 04:00:49.376104
# full_name                                             Catur Maryadi
# currency                                                        IDR
# email_domain                                              yahoo.com
#
#                                                                 4    \
# customer_id                                                      11
# first_name                                                    Najwa
# last_name                                                  Simbolon
# email                                       najwasimbolon@yahoo.com
# phone                                               (0276) 921-7073
# created_at_x                             2024-02-09 13:59:44.733151
# reservation_id                                                  164
# reservation_date                         2018-02-18 05:46:32.044000
# start_date                               2018-03-10 12:02:59.063000
# end_date                                 2018-03-23 09:23:56.599000
# total_price                                               1000000.0
# review            fantastic place stay sf stayed nov 9 2008 room...
# rating                                                            1
# created_at_y                             2025-01-26 06:11:04.642593
# payment_id                                                      164
# provider                                                        BSI
# account_number                                            124214471
# payment_status                                              Success
# payment_date                             2018-03-07 00:43:44.620445
# expire_date                              2018-03-10 12:02:59.063171
# full_name                                            Najwa Simbolon
# currency                                                        IDR
# email_domain                                              yahoo.com
#
#                                                                 5    \
# customer_id                                                      13
# first_name                                                      Oni
# last_name                                                   Mandala
# email                                          onimandala@gmail.com
# phone                                              +62-492-871-5943
# created_at_x                             2024-02-09 13:59:44.733151
# reservation_id                                                  350
# reservation_date                         2017-05-28 19:21:10.915000
# start_date                               2017-06-14 00:26:18.932000
# end_date                                 2017-06-18 03:54:42.063000
# total_price                                               9000000.0
# review            lovely located hotel stayed jury just night en...
# rating                                                            4
# created_at_y                             2025-01-26 06:11:04.687327
# payment_id                                                      350
# provider                                                        BNI
# account_number                                             45455649
# payment_status                                              Success
# payment_date                             2017-06-10 09:07:01.365411
# expire_date                              2017-06-14 00:26:18.932886
# full_name                                               Oni Mandala
# currency                                                        IDR
# email_domain                                              gmail.com
#
#                                                                 6    \
# customer_id                                                      14
# first_name                                                     Daru
# last_name                                                  Latupono
# email                                      darulatupono@hotmail.com
# phone                                            +62 (534) 599-5145
# created_at_x                             2024-02-09 13:59:44.733151
# reservation_id                                                   28
# reservation_date                         2017-02-04 01:48:49.112000
# start_date                               2017-02-18 06:59:20.424000
# end_date                                 2017-03-01 01:22:47.384000
# total_price                                               7000000.0
# review            great style service stayed granados 83 october...
# rating                                                            1
# created_at_y                             2025-01-26 06:11:04.611649
# payment_id                                                       28
# provider                                                    Mandiri
# account_number                                             56900633
# payment_status                                              Success
# payment_date                             2017-02-05 15:32:32.753439
# expire_date                              2017-02-18 06:59:20.424385
# full_name                                             Daru Latupono
# currency                                                        IDR
# email_domain                                            hotmail.com
#
#                                                                 7    \
# customer_id                                                      14
# first_name                                                     Daru
# last_name                                                  Latupono
# email                                      darulatupono@hotmail.com
# phone                                            +62 (534) 599-5145
# created_at_x                             2024-02-09 13:59:44.733151
# reservation_id                                                  172
# reservation_date                         2018-09-27 01:41:21.886000
# start_date                               2018-10-18 04:59:54.349000
# end_date                                 2018-10-26 17:53:04.600000
# total_price                                               9000000.0
# review            maria cristina location read reviews hotels me...
# rating                                                            5
# created_at_y                             2025-01-26 06:11:04.644796
# payment_id                                                      172
# provider                                                    Permata
# account_number                                             69235939
# payment_status                                              Success
# payment_date                             2018-09-28 06:14:54.129614
# expire_date                              2018-10-18 04:59:54.349504
# full_name                                             Daru Latupono
# currency                                                        IDR
# email_domain                                            hotmail.com
#
#                                                                 8    \
# customer_id                                                      14
# first_name                                                     Daru
# last_name                                                  Latupono
# email                                      darulatupono@hotmail.com
# phone                                            +62 (534) 599-5145
# created_at_x                             2024-02-09 13:59:44.733151
# reservation_id                                                  250
# reservation_date                         2015-04-03 07:34:48.228000
# start_date                               2015-04-25 09:52:54.235000
# end_date                                 2015-05-07 16:23:54.526000
# total_price                                               7000000.0
# review            wonderful stay wife stayed honeymoon 2 nights ...
# rating                                                            3
# created_at_y                             2025-01-26 06:11:04.665935
# payment_id                                                      250
# provider                                                        BNI
# account_number                                            113271810
# payment_status                                              Success
# payment_date                             2015-04-20 03:28:46.821408
# expire_date                              2015-04-25 09:52:54.235073
# full_name                                             Daru Latupono
# currency                                                        IDR
# email_domain                                            hotmail.com
#
#                                                                 9    ...  \
# customer_id                                                      25  ...
# first_name                                                    Setya  ...
# last_name                                                    Rajasa  ...
# email                                         setyarajasa@yahoo.com  ...
# phone                                            +62 (037) 621-7629  ...
# created_at_x                             2024-02-09 13:59:44.733151  ...
# reservation_id                                                  178  ...
# reservation_date                         2022-11-24 23:22:42.395000  ...
# start_date                               2022-11-30 14:20:27.780000  ...
# end_date                                 2022-12-12 10:42:05.923000  ...
# total_price                                               7000000.0  ...
# review            dreadful service poor experience dreadful serv...  ...
# rating                                                            4  ...
# created_at_y                             2025-01-26 06:11:04.647813  ...
# payment_id                                                      178  ...
# provider                                                        Ovo  ...
# account_number                                             10014277  ...
# payment_status                                              Success  ...
# payment_date                             2022-11-25 20:14:55.940342  ...
# expire_date                              2022-11-30 14:20:27.780655  ...
# full_name                                              Setya Rajasa  ...
# currency                                                        IDR  ...
# email_domain                                              yahoo.com  ...
#
#                                                                 390  \
# customer_id                                                     975
# first_name                                                    Kanda
# last_name                                                 Kurniawan
# email                                    kandakurniawan@hotmail.com
# phone                                                  086 554 1872
# created_at_x                             2024-02-09 13:59:44.733151
# reservation_id                                                   72
# reservation_date                         2016-02-03 14:22:04.975000
# start_date                               2016-02-11 15:01:20.193000
# end_date                                 2016-02-19 12:27:01.926000
# total_price                                               9000000.0
# review            not bad imagined, just returned 3 night stay h...
# rating                                                            1
# created_at_y                             2025-01-26 06:11:04.622161
# payment_id                                                       72
# provider                                                    Permata
# account_number                                             71608994
# payment_status                                              Success
# payment_date                             2016-02-07 00:26:54.307496
# expire_date                              2016-02-11 15:01:20.193673
# full_name                                           Kanda Kurniawan
# currency                                                        IDR
# email_domain                                            hotmail.com
#
#                                                                 391  \
# customer_id                                                     979
# first_name                                                  Shakila
# last_name                                                    Usamah
# email                                       shakilausamah@gmail.com
# phone                                                (076) 001 0041
# created_at_x                             2024-02-09 13:59:44.733151
# reservation_id                                                  102
# reservation_date                         2018-10-20 20:38:00.445000
# start_date                               2018-11-16 18:14:40.984000
# end_date                                 2018-11-19 15:06:00.984000
# total_price                                              11000000.0
# review            lan kwai fong hotel hong kong- decidedly avera...
# rating                                                            1
# created_at_y                             2025-01-26 06:11:04.629088
# payment_id                                                      102
# provider                                                        BRI
# account_number                                             78226735
# payment_status                                              Success
# payment_date                             2018-11-02 08:47:58.713702
# expire_date                              2018-11-16 18:14:40.984145
# full_name                                            Shakila Usamah
# currency                                                        IDR
# email_domain                                              gmail.com
#
#                                                                 392  \
# customer_id                                                     986
# first_name                                                     Febi
# last_name                                                  Marpaung
# email                                      febimarpaung@hotmail.com
# phone                                            +62 (029) 365-3098
# created_at_x                             2024-02-09 13:59:44.733151
# reservation_id                                                   64
# reservation_date                         2015-11-13 17:41:50.517000
# start_date                               2015-11-20 06:28:29.081000
# end_date                                 2015-11-25 13:51:50.784000
# total_price                                               9000000.0
# review            fab hotel arrived today n't hesitate using hot...
# rating                                                            4
# created_at_y                             2025-01-26 06:11:04.619907
# payment_id                                                       64
# provider                                                       Dana
# account_number                                             89704042
# payment_status                                              Success
# payment_date                             2015-11-18 22:08:04.793063
# expire_date                              2015-11-20 06:28:29.081883
# full_name                                             Febi Marpaung
# currency                                                        IDR
# email_domain                                            hotmail.com
#
#                                                                 393  \
# customer_id                                                     987
# first_name                                                  Warsita
# last_name                                               Simanjuntak
# email                                  warsitasimanjuntak@gmail.com
# phone                                              +62-005-639-8178
# created_at_x                             2024-02-09 13:59:44.733151
# reservation_id                                                   42
# reservation_date                         2022-07-31 18:19:08.357000
# start_date                               2022-08-24 09:26:35.508000
# end_date                                 2022-08-30 18:06:49.685000
# total_price                                               9000000.0
# review            fantastic ask, partner just got hoxton anniver...
# rating                                                            4
# created_at_y                             2025-01-26 06:11:04.613985
# payment_id                                                       42
# provider                                                    Permata
# account_number                                             20744456
# payment_status                                              Success
# payment_date                             2022-08-12 06:55:05.659188
# expire_date                              2022-08-24 09:26:35.508498
# full_name                                       Warsita Simanjuntak
# currency                                                        IDR
# email_domain                                              gmail.com
#
#                                                                 394  \
# customer_id                                                     988
# first_name                                                   Gangsa
# last_name                                                  Suryatmi
# email                                    gangsasuryatmi@hotmail.com
# phone                                               (0917) 672-9281
# created_at_x                             2024-02-09 13:59:44.733151
# reservation_id                                                  307
# reservation_date                         2023-12-15 09:15:04.802000
# start_date                               2023-12-26 00:14:26.880000
# end_date                                 2024-01-04 17:40:05.060000
# total_price                                               9000000.0
# review            strange good husband stayed relais uffizi nigh...
# rating                                                            2
# created_at_y                             2025-01-26 06:11:04.679021
# payment_id                                                      307
# provider                                                       Dana
# account_number                                             87974272
# payment_status                                              Success
# payment_date                             2023-12-16 04:29:30.000422
# expire_date                              2023-12-26 00:14:26.880354
# full_name                                           Gangsa Suryatmi
# currency                                                        IDR
# email_domain                                            hotmail.com
#
#                                                                 395  \
# customer_id                                                     991
# first_name                                                  Kasiran
# last_name                                                   Pranowo
# email                                    kasiranpranowo@hotmail.com
# phone                                              +62-151-668-9685
# created_at_x                             2024-02-09 13:59:44.733151
# reservation_id                                                  322
# reservation_date                         2020-05-31 01:48:18.964000
# start_date                               2020-06-27 06:31:51.097000
# end_date                                 2020-07-08 03:27:40.849000
# total_price                                              13000000.0
# review            great location great service stayed excellent ...
# rating                                                            2
# created_at_y                             2025-01-26 06:11:04.681145
# payment_id                                                      322
# provider                                                        BCA
# account_number                                             62572068
# payment_status                                              Success
# payment_date                             2020-06-16 00:33:16.268677
# expire_date                              2020-06-27 06:31:51.097933
# full_name                                           Kasiran Pranowo
# currency                                                        IDR
# email_domain                                            hotmail.com
#
#                                                                 396  \
# customer_id                                                     993
# first_name                                                  Harjaya
# last_name                                                   Hartati
# email                                      harjayahartati@yahoo.com
# phone                                             +62 (84) 043-5736
# created_at_x                             2024-02-09 13:59:44.733151
# reservation_id                                                  180
# reservation_date                         2018-05-20 22:30:51.744000
# start_date                               2018-06-05 11:57:28.949000
# end_date                                 2018-06-12 04:43:46.331000
# total_price                                               3000000.0
# review            lucky discovery having spent months florence y...
# rating                                                            2
# created_at_y                             2025-01-26 06:11:04.647813
# payment_id                                                      180
# provider                                                        BNI
# account_number                                            126038312
# payment_status                                              Success
# payment_date                             2018-05-25 02:37:08.440257
# expire_date                              2018-06-05 11:57:28.949289
# full_name                                           Harjaya Hartati
# currency                                                        IDR
# email_domain                                              yahoo.com
#
#                                                                 397  \
# customer_id                                                     995
# first_name                                                    Irfan
# last_name                                                   Maryadi
# email                                        irfanmaryadi@gmail.com
# phone                                              +62-057-742-8019
# created_at_x                             2024-02-09 13:59:44.733151
# reservation_id                                                   86
# reservation_date                         2022-06-25 18:25:26.577000
# start_date                               2022-06-27 17:39:58.972000
# end_date                                 2022-07-02 20:36:45.339000
# total_price                                              11000000.0
# review            great room location service price recently sta...
# rating                                                            3
# created_at_y                             2025-01-26 06:11:04.624541
# payment_id                                                       86
# provider                                                    Permata
# account_number                                            119271005
# payment_status                                              Success
# payment_date                             2022-06-26 10:53:36.921245
# expire_date                              2022-06-27 17:39:58.972960
# full_name                                             Irfan Maryadi
# currency                                                        IDR
# email_domain                                              gmail.com
#
#                                                                 398  \
# customer_id                                                     996
# first_name                                                     Jono
# last_name                                                   Maryadi
# email                                       jonomaryadi@hotmail.com
# phone                                            +62 (042) 227-3166
# created_at_x                             2024-02-09 13:59:44.733151
# reservation_id                                                  241
# reservation_date                         2016-01-19 10:19:12.907000
# start_date                               2016-01-26 08:08:00.170000
# end_date                                 2016-02-08 21:50:36.990000
# total_price                                               7000000.0
# review            askanischer hof, hotel, family stayed askanisc...
# rating                                                            1
# created_at_y                             2025-01-26 06:11:04.663612
# payment_id                                                      241
# provider                                                        BNI
# account_number                                             88865047
# payment_status                                              Success
# payment_date                             2016-01-21 03:20:08.047553
# expire_date                              2016-01-26 08:08:00.170447
# full_name                                              Jono Maryadi
# currency                                                        IDR
# email_domain                                            hotmail.com
#
#                                                                 399
# customer_id                                                    1000
# first_name                                                 Heryanto
# last_name                                                   Siregar
# email                                   heryantosiregar@hotmail.com
# phone                                                    0800101666
# created_at_x                             2024-02-09 13:59:44.733151
# reservation_id                                                   62
# reservation_date                         2016-06-22 16:38:50.950000
# start_date                               2016-07-01 17:54:37.944000
# end_date                                 2016-07-08 15:56:10.137000
# total_price                                               1000000.0
# review            bit obviously invested lot make good hotel, 1-...
# rating                                                            4
# created_at_y                             2025-01-26 06:11:04.619907
# payment_id                                                       62
# provider                                                        Ovo
# account_number                                             98612293
# payment_status                                              Success
# payment_date                             2016-06-25 07:11:03.340820
# expire_date                              2016-07-01 17:54:37.944352
# full_name                                          Heryanto Siregar
# currency                                                        IDR
# email_domain                                            hotmail.com
#
# [23 rows x 400 columns]

# %% [markdown]
# ### Check Validation

# %%
def check_datatype():
    for col in final_df.columns:
        print("====================================")
        print(f"{col} : {final_df[col].dtype}")

# %%
check_datatype()
# Out:
# ====================================
# customer_id : int64
# ====================================
# first_name : object
# ====================================
# last_name : object
# ====================================
# email : object
# ====================================
# phone : object
# ====================================
# created_at_x : datetime64[ns]
# ====================================
# reservation_id : int64
# ====================================
# reservation_date : datetime64[ns]
# ====================================
# start_date : datetime64[ns]
# ====================================
# end_date : datetime64[ns]
# ====================================
# total_price : float64
# ====================================
# review : object
# ====================================
# rating : int64
# ====================================
# created_at_y : datetime64[ns]
# ====================================
# payment_id : int64
# ====================================
# provider : object
# ====================================
# account_number : int64
# ====================================
# payment_status : object
# ====================================
# payment_date : object
# ====================================
# expire_date : object
# ====================================
# full_name : object
# ====================================
# currency : object
# ====================================
# email_domain : object

# %%
def select_col(df):
    # Select specific columns from final_df
    selected_columns = ['reservation_id', 'full_name', 'email', 'email_domain', 'reservation_date', 'payment_date', 'start_date', 'end_date', 'total_price', 'currency', 'provider', 'payment_status']
    df = df[selected_columns]
    return df

# %%
final_df = select_col(final_df)
final_df.head()
# Out:
#    reservation_id          full_name                        email  \
# 0             139   Estiawan Saragih  estiawansaragih@hotmail.com
# 1              49  Drajat Nainggolan   drajatnainggolan@yahoo.com
# 2             372       Simon Wacana      simonwacana@hotmail.com
# 3             384      Catur Maryadi       caturmaryadi@yahoo.com
# 4             164     Najwa Simbolon      najwasimbolon@yahoo.com
#
#   email_domain        reservation_date                payment_date  \
# 0  hotmail.com 2016-08-30 18:52:49.985  2016-09-15 14:06:21.733799
# 1    yahoo.com 2021-09-11 04:17:09.909  2021-09-30 22:51:39.392363
# 2  hotmail.com 2018-05-01 20:26:20.625                        None
# 3    yahoo.com 2023-07-04 00:32:43.303                        None
# 4    yahoo.com 2018-02-18 05:46:32.044  2018-03-07 00:43:44.620445
#
#                start_date                end_date  total_price currency  \
# 0 2016-09-20 18:18:02.814 2016-09-25 21:35:42.582    1000000.0      IDR
# 1 2021-10-02 02:48:59.764 2021-10-04 09:03:50.491   13000000.0      IDR
# 2 2018-05-28 17:52:10.698 2018-06-04 10:00:05.209    9000000.0      IDR
# 3 2023-08-03 04:00:49.376 2023-08-15 02:53:20.540    3000000.0      IDR
# 4 2018-03-10 12:02:59.063 2018-03-23 09:23:56.599    1000000.0      IDR
#
#   provider payment_status
# 0      Ovo        Success
# 1     Dana        Success
# 2      Ovo        Waiting
# 3  Permata         Failed
# 4      BSI        Success

# %% [markdown]
# ### Check Missing

# %%
def check_missing_value():
    """
    Check for missing values in the DataFrame and calculate the percentage of missing values for each column.

    Parameters:
        final_df (pd.DataFrame): The DataFrame to check for missing values.

    Returns:
        pd.DataFrame: A DataFrame containing the count and percentage of missing values for each column.
    """
    # Check for missing values
    missing_values = final_df.isnull().sum()
    missing_percentage = (missing_values / len(final_df)) * 100

    # Combine results into a DataFrame
    missing_info = pd.DataFrame({
        'Missing Values': missing_values,
        'Missing Percentage': missing_percentage
    })

    return missing_info

# %%
check_missing_value()
# Out:
#                   Missing Values  Missing Percentage
# reservation_id                 0                 0.0
# full_name                      0                 0.0
# email                          0                 0.0
# email_domain                   0                 0.0
# reservation_date               0                 0.0
# payment_date                  84                21.0
# start_date                     0                 0.0
# end_date                       0                 0.0
# total_price                    0                 0.0
# currency                       0                 0.0
# provider                       0                 0.0
# payment_status                 0                 0.0

# %%
import matplotlib.pyplot as plt

def visualize_missing_values(final_df):
    """
    Visualize the percentage of missing values in each column using a bar plot.
    """
    missing_info = check_missing_value(final_df)
    missing_info['Missing Percentage'].plot(kind='bar', title='Percentage of Missing Values by Column')
    plt.xlabel('Columns')
    plt.ylabel('Missing Percentage')
    plt.show()

# Visualize missing values
visualize_missing_values(final_df)

# %%
# Filling Missing Values

def fill_missing_values():
    # Fill missing values in the 'payment_status' column with 'Not Paid'
    final_df['payment_date'].fillna('Missing Data', inplace=True)


    # Check for missing values after filling
    return check_missing_value()

# %%
fill_missing_values()
# Out:
# C:\Users\US3R\AppData\Local\Temp\ipykernel_31112\2352423217.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   final_df['payment_date'].fillna('Missing Data', inplace=True)
# C:\Users\US3R\AppData\Local\Temp\ipykernel_31112\2352423217.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['payment_date'].fillna('Missing Data', inplace=True)
#                   Missing Values  Missing Percentage
# reservation_id                 0                 0.0
# full_name                      0                 0.0
# email                          0                 0.0
# email_domain                   0                 0.0
# reservation_date               0                 0.0
# payment_date                   0                 0.0
# start_date                     0                 0.0
# end_date                       0                 0.0
# total_price                    0                 0.0
# currency                       0                 0.0
# provider                       0                 0.0
# payment_status                 0                 0.0

# %% [markdown]
# # Load

# %% [markdown]
# ## Create Load Engine
#
# new engine to load

# %%
import os
import pandas as pd
from sqlalchemy import create_engine
from dotenv import load_dotenv

def load_data_to_neon(df, table_name):
    """
    Load data from a DataFrame into a Neon PostgreSQL table.

    Parameters:
        df (pd.DataFrame): The DataFrame containing the data to insert.
        table_name (str): The name of the table in the Neon database.
    """
    # Load environment variables from .env file
    load_dotenv()

    # Fetch environment variables
    db_user = os.getenv('DB_USER_Neon')
    db_password = os.getenv('DB_PASSWORD_Neon')
    db_host = os.getenv('DB_HOST_Neon')
    db_name = os.getenv('DB_NAME_Neon')
    db_sslmode = os.getenv('DB_SSLMODE_Neon')

    # Create the connection string
    connection_string = f"postgresql://{db_user}:{db_password}@{db_host}/{db_name}?sslmode={db_sslmode}"

    # Create SQLAlchemy engine
    engine = create_engine(connection_string)

    try:
        # Insert DataFrame into Neon
        df.to_sql(table_name, engine, if_exists='append', index=False)
        print(f"Data inserted into table '{table_name}' successfully.")
    except Exception as e:
        print(f"Error inserting data into Neon: {e}")

#

# %%
load_data_to_neon(df, 'transformed_table')
# Out:
# Data inserted into table 'transformed_table' successfully.

# %% [markdown]
# ## Retrieve Data from Neon

# %%
import os
import pandas as pd
from sqlalchemy import create_engine
from dotenv import load_dotenv

def retrieve_data_from_neon(query):
    """
    Retrieve data from a Neon PostgreSQL database.

    Parameters:
        query (str): The SQL query to execute.

    Returns:
        pd.DataFrame: A DataFrame containing the query results.
    """
    # Load environment variables from .env file
    load_dotenv()

    # Fetch environment variables
    db_user = os.getenv('DB_USER_Neon')
    db_password = os.getenv('DB_PASSWORD_Neon')
    db_host = os.getenv('DB_HOST_Neon')
    db_name = os.getenv('DB_NAME_Neon')
    db_sslmode = os.getenv('DB_SSLMODE_Neon')

    # Create the connection string
    connection_string = f"postgresql://{db_user}:{db_password}@{db_host}/{db_name}?sslmode={db_sslmode}"

    # Create SQLAlchemy engine
    engine = create_engine(connection_string)

    try:
        # Execute the query and load results into a DataFrame
        df = pd.read_sql(query, engine)
        print("Data retrieved successfully!")
        return df
    except Exception as e:
        print(f"Error retrieving data from Neon: {e}")
        return None

# Example usage
if __name__ == "__main__":
    # Example SQL query
    query = "SELECT * FROM transformed_table;"  # Replace with your table name

    # Call the function to retrieve data
    data = retrieve_data_from_neon(query)

    # Display the retrieved data
    if data is not None:
        print(data)
# Out:
# Data retrieved successfully!
#      payment_id  reservation_id provider  account_number payment_status  \
# 0             1               1      Ovo        38137149        Success
# 1             2               2      BCA        42103729        Success
# 2             3               3  Permata        58689635        Success
# 3             4               4      BNI       107161965        Success
# 4             5               5      BSI        14334131         Failed
# ..          ...             ...      ...             ...            ...
# 396         397             397  Permata        87836019        Success
# 397         398             398  Mandiri        50997930         Failed
# 398         399             399      Ovo        44305033        Success
# 399         400             400      BNI        84875963        Success
# 400         401             401      BCA        11111111        Success
#
#                    payment_date                 expire_date
# 0    2020-10-20 17:07:04.406780  2020-10-28 18:10:37.175108
# 1    2015-02-28 16:44:56.703511  2015-03-08 05:27:33.443131
# 2    2022-04-03 13:27:30.811447  2022-04-06 14:20:57.846492
# 3    2019-10-04 08:39:56.034805  2019-10-08 02:01:21.209415
# 4                          None  2020-06-14 12:02:55.669148
# ..                          ...                         ...
# 396  2018-08-05 09:22:05.983116  2018-08-27 12:44:56.532991
# 397                        None  2022-04-19 12:35:51.127022
# 398  2015-12-12 22:35:15.569310  2015-12-19 19:28:08.809478
# 399  2021-07-29 16:38:06.052542  2021-08-02 22:27:28.713637
# 400  2024-02-14 00:30:15.052542  2024-02-15 00:30:15.052542
#
# [401 rows x 7 columns]
